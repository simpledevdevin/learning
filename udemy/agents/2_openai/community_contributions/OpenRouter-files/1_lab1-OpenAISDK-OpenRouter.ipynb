# %% [markdown]
# ## Week 2 Day 1
#
# And now! Our first look at OpenAI Agents SDK
#
# You won't believe how lightweight this is..

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">The OpenAI Agents SDK Docs</h2>
#             <span style="color:#00bfff;">The documentation on OpenAI Agents SDK is really clear and simple: <a href="https://openai.github.io/openai-agents-python/">https://openai.github.io/openai-agents-python/</a> and it's well worth a look. (Remember this is the OpenRouter form.)
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# The imports

import os
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
# The usual starting point

load_dotenv(override=True)

# Map OpenRouter credentials to OpenAI-compatible env vars
if os.getenv("OPENROUTER_API_KEY"):
    os.environ["OPENAI_API_KEY"] = os.getenv("OPENROUTER_API_KEY")
if os.getenv("OPENROUTER_API_BASE"):
    os.environ["OPENAI_BASE_URL"] = os.getenv("OPENROUTER_API_BASE")

# %%
# Make an agent with name, instructions, model (choose model here, not in .env) and the base url in the .env
model = "openai/gpt-oss-20b:free"
agent = Agent(name="Jokester", instructions="You are a joke teller, do not Respond in markdown", model=model)

# %%
# Run the joke with Runner.run(agent, prompt) then print final_output
# If you are wondering, Yes, its normal to have a [non-fatal] 401 error in the output

with trace("Telling a joke"):
    result = await Runner.run(agent, "Tell me a joke about bears.")
    print(result.final_output)
# Out:
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************f46c. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }
# Why do bears break up with their girlfriends?
#
# Because they can’t handle the *bear*ing of a relationship!
# [non-fatal] Tracing client error 401: {
#   "error": {
#     "message": "Incorrect API key provided: sk-or-v1*************************************************************f46c. You can find your API key at https://platform.openai.com/account/api-keys.",
#     "type": "invalid_request_error",
#     "param": null,
#     "code": "invalid_api_key"
#   }
# }

# %% [markdown]
# ## Now go and look at the **trace**
#
# But actually **don't**. `OpenRouter` doesn't have any **traces**
